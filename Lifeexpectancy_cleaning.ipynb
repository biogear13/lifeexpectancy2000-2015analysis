# %% [markdown]
# # Life expectancy

# %% [markdown]
# # Import  the necessary packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Open the data

# %%
lifeexpectancy = pd.read_csv('Life Expectancy Data.csv')
lifeexpectancy.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# # Data Cleaning

# %%
lifeexpectancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %% [markdown]
# - Change the column names to remove the spaces

# %%
le2 = lifeexpectancy.rename({'Life expectancy ':'life_expectancy', 'Adult Mortality':'adult_mortality', 'infant deaths':'infant_deaths',
                             'percentage expenditure':'perc_expend', 'Hepatitis B':'hepa_b', 'Measles ':'measles', ' BMI ':'BMI',
                             'under-five deaths ': 'underfive_deaths', 'Total expenditure': 'total_expenditure', 'Diphtheria ': 'diphtheria',
                             ' HIV/AIDS':'hiv', ' thinness  1-19 years':'thinness_10_19', ' thinness 5-9 years':'thinness_5_9',
                             'Income composition of resources':'income_comp'}, axis=1)
le2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            2938 non-null   object
#  1   Year               2938 non-null   int64
#  2   Status             2938 non-null   object
#  3   life_expectancy    2928 non-null   float64
#  4   adult_mortality    2928 non-null   float64
#  5   infant_deaths      2938 non-null   int64
#  6   Alcohol            2744 non-null   float64
#  7   perc_expend        2938 non-null   float64
#  8   hepa_b             2385 non-null   float64
#  9   measles            2938 non-null   int64
#  10  BMI                2904 non-null   float64
#  11  underfive_deaths   2938 non-null   int64
#  12  Polio              2919 non-null   float64
#  13  total_expenditure  2712 non-null   float64
#  14  diphtheria         2919 non-null   float64
#  15  hiv                2938 non-null   float64
# ...

# %%
#change year to text
le2['Year']=le2['Year'].astype(str)

# %%
le2.shape
# Out:
# (2938, 22)

# %%
lifeexpectancy.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %% [markdown]
# - Polio and Diphtheria vaccination have values that has less than 10

# %%
le2[le2['Polio']<10][['Country','Year','Polio']]
# Out:
#           Country  Year  Polio
# 0     Afghanistan  2015    6.0
# 11    Afghanistan  2004    5.0
# 48         Angola  2015    7.0
# 59         Angola  2004    4.0
# 60         Angola  2003    4.0
# ...           ...   ...    ...
# 2906       Zambia  2015    9.0
# 2909       Zambia  2012    7.0
# 2911       Zambia  2010    8.0
# 2913       Zambia  2008    9.0
# 2934     Zimbabwe  2003    7.0
#
# [172 rows x 3 columns]

# %%
le2[le2['diphtheria']<10][['Country','Year','diphtheria']]
# Out:
#                                  Country  Year  diphtheria
# 11                           Afghanistan  2004         5.0
# 54                                Angola  2009         6.0
# 59                                Angola  2004         4.0
# 60                                Angola  2003         4.0
# 106                              Armenia  2005         9.0
# ...                                  ...   ...         ...
# 2865  Venezuela (Bolivarian Republic of)  2008         5.0
# 2872  Venezuela (Bolivarian Republic of)  2001         7.0
# 2906                              Zambia  2015         9.0
# 2914                              Zambia  2007         8.0
# 2931                            Zimbabwe  2006         7.0
#
# [170 rows x 3 columns]

# %%
le2['Polio']=le2['Polio'].apply(lambda x: x if x>=10 else x*10)

# %%
le2['diphtheria']=le2['diphtheria'].apply(lambda x: x if x>=10 else x*10)

# %% [markdown]
# - Maximum life expectancy in the dataset is 89 but according to worldbank the maximum life expectancy recorded by any country was 85. Since there was a discrepancy, I would use the world bank data.

# %%
# get the life expectancy from worldbank
lifeexwb_df = pd.read_csv('life_expectancy_worldbank.csv')
# melt the lifeexpectancy df
lifeex_melted = pd.melt(lifeexwb_df, id_vars=['Country Name'], value_vars=['2000','2001','2002','2003','2004','2005','2006','2007','2008','2009',
                                                                              '2010','2011','2012','2013','2014','2015'], var_name='Year', value_name='life_expectancy_wb')
lifeex_melted
# Out:
#                             Country Name  Year  life_expectancy_wb
# 0                            Afghanistan  2000              55.298
# 1                                Albania  2000              75.404
# 2                                Algeria  2000              70.478
# 3                                 Angola  2000              41.270
# 4                    Antigua and Barbuda  2000              74.606
# ...                                  ...   ...                 ...
# 3131  Venezuela (Bolivarian Republic of)  2015              73.006
# 3132                            Viet Nam  2015              73.876
# 3133                               Yemen  2015              65.873
# 3134                              Zambia  2015              61.208
# 3135                            Zimbabwe  2015              59.591
#
# [3136 rows x 3 columns]

# %%
#join pop_gdp to le2
le2 = le2.merge(lifeex_melted, left_on=['Country','Year'], right_on=['Country Name','Year'], how='left')
le2 = le2.drop(columns=['life_expectancy','Country Name'])
le2.head()
# Out:
#        Country  Year      Status  adult_mortality  infant_deaths  Alcohol  \
# 0  Afghanistan  2015  Developing            263.0             62     0.01
# 1  Afghanistan  2014  Developing            271.0             64     0.01
# 2  Afghanistan  2013  Developing            268.0             66     0.01
# 3  Afghanistan  2012  Developing            272.0             69     0.01
# 4  Afghanistan  2011  Developing            275.0             71     0.01
#
#    perc_expend  hepa_b  measles   BMI  ...  total_expenditure  diphtheria  \
# 0    71.279624    65.0     1154  19.1  ...               8.16        65.0
# 1    73.523582    62.0      492  18.6  ...               8.18        62.0
# 2    73.219243    64.0      430  18.1  ...               8.13        64.0
# 3    78.184215    67.0     2787  17.6  ...               8.52        67.0
# 4     7.097109    68.0     3013  17.2  ...               7.87        68.0
#
# ...

# %% [markdown]
# - Evaluate the missing values

# %%
le2.isnull().sum()
# Out:
# Country                 0
# Year                    0
# Status                  0
# adult_mortality        10
# infant_deaths           0
# Alcohol               194
# perc_expend             0
# hepa_b                553
# measles                 0
# BMI                    34
# underfive_deaths        0
# Polio                  19
# total_expenditure     226
# diphtheria             19
# hiv                     0
# GDP                   448
# Population            652
# thinness_10_19         34
# thinness_5_9           34
# income_comp           167
# Schooling             163
# life_expectancy_wb      9
# dtype: int64

# %%
# Check the null valies in life expectancy
le2[le2['life_expectancy_wb'].isnull()]
# Out:
#                     Country  Year      Status  adult_mortality  infant_deaths  \
# 624            Cook Islands  2013  Developing              NaN              0
# 769                Dominica  2013  Developing              NaN              0
# 1650       Marshall Islands  2013  Developing              NaN              0
# 1715                 Monaco  2013  Developing              NaN              0
# 1812                  Nauru  2013  Developing              NaN              0
# 1909                   Niue  2013  Developing              NaN              0
# 1958                  Palau  2013  Developing              NaN              0
# 2167  Saint Kitts and Nevis  2013  Developing              NaN              0
# 2216             San Marino  2013  Developing              NaN              0
#
#       Alcohol  perc_expend  hepa_b  measles   BMI  ...  total_expenditure  \
# 624      0.01     0.000000    98.0        0  82.8  ...               3.58
# ...

# %%
# I opted to remove the null values of the life expectancy
le2.dropna(subset=['life_expectancy_wb'], inplace=True)

# %%
le2.shape
# Out:
# (2929, 22)

# %%
le2.isnull().sum().divide(2928).multiply(100)
# Out:
# Country                0.000000
# Year                   0.000000
# Status                 0.000000
# adult_mortality        0.034153
# infant_deaths          0.000000
# Alcohol                6.591530
# perc_expend            0.000000
# hepa_b                18.886612
# measles                0.000000
# BMI                    1.092896
# underfive_deaths       0.000000
# Polio                  0.648907
# total_expenditure      7.718579
# diphtheria             0.648907
# hiv                    0.000000
# GDP                   15.129781
# Population            21.994536
# thinness_10_19         1.092896
# thinness_5_9           1.092896
# income_comp            5.498634
# Schooling              5.464481
# life_expectancy_wb     0.000000
# dtype: float64

# %%
# Evaluate the missing data for Polio
le2[le2['Polio'].isnull()][['Country','Year','Polio','diphtheria']]
# Out:
#           Country  Year  Polio  diphtheria
# 1742   Montenegro  2005    NaN         NaN
# 1743   Montenegro  2004    NaN         NaN
# 1744   Montenegro  2003    NaN         NaN
# 1745   Montenegro  2002    NaN         NaN
# 1746   Montenegro  2001    NaN         NaN
# 1747   Montenegro  2000    NaN         NaN
# 2414  South Sudan  2010    NaN         NaN
# 2415  South Sudan  2009    NaN         NaN
# 2416  South Sudan  2008    NaN         NaN
# 2417  South Sudan  2007    NaN         NaN
# 2418  South Sudan  2006    NaN         NaN
# 2419  South Sudan  2005    NaN         NaN
# 2420  South Sudan  2004    NaN         NaN
# 2421  South Sudan  2003    NaN         NaN
# 2422  South Sudan  2002    NaN         NaN
# 2423  South Sudan  2001    NaN         NaN
# 2424  South Sudan  2000    NaN         NaN
# 2615  Timor-Leste  2001    NaN         NaN
# 2616  Timor-Leste  2000    NaN         NaN

# %% [markdown]
# Evaluate status

# %%
le2['Status'].unique()
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %%
# Check the countries that were classified as developed
le2[le2['Status']=='Developed']['Country'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus',
#        'Czechia', 'Denmark', 'Germany', 'Hungary', 'Iceland', 'Ireland',
#        'Italy', 'Japan', 'Latvia', 'Lithuania', 'Luxembourg', 'Malta',
#        'Netherlands', 'New Zealand', 'Norway', 'Poland', 'Portugal',
#        'Romania', 'Singapore', 'Slovakia', 'Slovenia', 'Spain', 'Sweden',
#        'Switzerland',
#        'United Kingdom of Great Britain and Northern Ireland',
#        'United States of America'], dtype=object)

# %% [markdown]
# It could be seen that some countries classified as developed such as 'Canada' were miscategorized.

# %%
# get the corrected country status
status = pd.read_csv('country status.csv')
status.head()
# Out:
#      Country Status_revised
# 0  Australia      Developed
# 1    Austria      Developed
# 2    Belgium      Developed
# 3   Bulgaria      Developed
# 4     Canada      Developed

# %%
# merge status table to le2
map_status = dict(status[['Country','Status_revised']].values)
le2['Status'] = le2['Country'].map(map_status)

# %%
# Check
le2[le2['Status']=='Developed']['Country'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Bulgaria', 'Canada', 'Croatia',
#        'Cyprus', 'Czechia', 'Denmark', 'Estonia', 'Finland', 'France',
#        'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy',
#        'Japan', 'Latvia', 'Lithuania', 'Luxembourg', 'Malta',
#        'Netherlands', 'New Zealand', 'Norway', 'Poland', 'Portugal',
#        'Romania', 'Singapore', 'Slovakia', 'Slovenia', 'Spain', 'Sweden',
#        'Switzerland',
#        'United Kingdom of Great Britain and Northern Ireland',
#        'United States of America'], dtype=object)

# %% [markdown]
# Evaluate Population

# %%
# What are the countries with missing population
le2[le2['Population'].isnull()]['Country'].unique()
# Out:
# array(['Antigua and Barbuda', 'Bahamas', 'Bahrain', 'Barbados',
#        'Bolivia (Plurinational State of)', 'Brunei Darussalam',
#        "Côte d'Ivoire", 'Congo', 'Cuba', 'Czechia',
#        "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Egypt', 'Eritrea', 'Gambia',
#        'Grenada', 'Iran (Islamic Republic of)', 'Kuwait', 'Kyrgyzstan',
#        "Lao People's Democratic Republic", 'Libya',
#        'Micronesia (Federated States of)', 'New Zealand', 'Oman', 'Qatar',
#        'Republic of Korea', 'Republic of Moldova', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Saudi Arabia', 'Singapore',
#        'Slovakia', 'Somalia', 'The former Yugoslav republic of Macedonia',
#        'United Arab Emirates',
#        'United Kingdom of Great Britain and Northern Ireland',
#        'United Republic of Tanzania', 'United States of America',
#        'Venezuela (Bolivarian Republic of)', 'Viet Nam', 'Yemen'],
#       dtype=object)

# %% [markdown]
# Since there are significant number of items that were missing for population and gdp, I supplemented it from data from the world bank

# %%
# get the population
population = pd.read_csv('population.csv')
population.head()
# Out:
#           Country Name      2000      2001      2002      2003      2004  \
# 0          Afghanistan  19542982  19688632  21000256  22645130  23553551
# 1              Albania   3089027   3060173   3051010   3039616   3026939
# 2              Algeria  30774621  31200985  31624696  32055883  32510186
# 3               Angola   6578230   6802494   7032713   7266780   7511895
# 4  Antigua and Barbuda     75055     76215     77195     78075     78941
#
#        2005      2006      2007      2008      2009      2010      2011  \
# 0  24411191  25442944  25903301  26427199  27385307  28189672  29249157
# 1   3011487   2992547   2970017   2947314   2927519   2913021   2905195
# 2  32956690  33435080  33983827  34569592  35196037  35856344  36543541
# 3   7771590   8043218   8330047   8631457   8947152   9276707   9617702
# 4     79869     80895     82016     83251     84534     85695     86729
#
#        2012      2013      2014      2015
# 0  30466479  31541209  32716210  33753499
# ...

# %%
# melt the population df
population_melted = pd.melt(population, id_vars=['Country Name'], value_vars=['2000','2001','2002','2003','2004','2005','2006','2007','2008','2009',
                                                                              '2010','2011','2012','2013','2014','2015'], var_name='Year', value_name='population_wb')
population_melted
# Out:
#                             Country Name  Year  population_wb
# 0                            Afghanistan  2000       19542982
# 1                                Albania  2000        3089027
# 2                                Algeria  2000       30774621
# 3                                 Angola  2000        6578230
# 4                    Antigua and Barbuda  2000          75055
# ...                                  ...   ...            ...
# 3099  Venezuela (Bolivarian Republic of)  2015       30529716
# 3100                            Viet Nam  2015       92191398
# 3101                               Yemen  2015       28516545
# 3102                              Zambia  2015       16248230
# 3103                            Zimbabwe  2015       14154937
#
# [3104 rows x 3 columns]

# %%
#get the gdp
gdp = pd.read_csv('gdp.csv')
# melt the population df
gdp_melted = pd.melt(gdp, id_vars=['Country Name'], value_vars=['2000','2001','2002','2003','2004','2005','2006','2007','2008','2009',
                                                                              '2010','2011','2012','2013','2014','2015'], var_name='Year', value_name='gdb_wb')
gdp_melted
# Out:
#                             Country Name  Year        gdb_wb
# 0                            Afghanistan  2000           NaN
# 1                                Albania  2000  3.480355e+09
# 2                                Algeria  2000  5.479039e+10
# 3                                 Angola  2000  9.129595e+09
# 4                    Antigua and Barbuda  2000  8.263704e+08
# ...                                  ...   ...           ...
# 3131  Venezuela (Bolivarian Republic of)  2015           NaN
# 3132                            Viet Nam  2015  2.392583e+11
# 3133                               Yemen  2015  4.244450e+10
# 3134                              Zambia  2015  2.125122e+10
# 3135                            Zimbabwe  2015  1.996312e+10
#
# [3136 rows x 3 columns]

# %%
#join population and gdp
pop_gdp=population_melted.merge(gdp_melted, on=['Country Name','Year'], how='left')
pop_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3104 entries, 0 to 3103
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   3104 non-null   object
#  1   Year           3104 non-null   object
#  2   population_wb  3104 non-null   int64
#  3   gdb_wb         3014 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 121.2+ KB

# %%
#join pop_gdp to le2
le3 = le2.merge(pop_gdp, left_on=['Country','Year'], right_on=['Country Name','Year'], how='left')
country_class = pd.read_csv('category.csv')
le3.columns
# Out:
# Index(['Country', 'Year', 'Status', 'adult_mortality', 'infant_deaths',
#        'Alcohol', 'perc_expend', 'hepa_b', 'measles', 'BMI',
#        'underfive_deaths', 'Polio', 'total_expenditure', 'diphtheria', 'hiv',
#        'GDP', 'Population', 'thinness_10_19', 'thinness_5_9', 'income_comp',
#        'Schooling', 'life_expectancy_wb', 'Country Name', 'population_wb',
#        'gdb_wb'],
#       dtype='object')

# %%
le3 = le3.merge(country_class, on=['Country Name'], how='left')
le3 = le3.drop(columns=['GDP','Population','Country Name'])

# %%
le3.isnull().sum().divide(2928).multiply(100)
# Out:
# Country                0.000000
# Year                   0.000000
# Status                 0.000000
# adult_mortality        0.034153
# infant_deaths          0.000000
# Alcohol                6.591530
# perc_expend            0.000000
# hepa_b                18.886612
# measles                0.000000
# BMI                    1.092896
# underfive_deaths       0.000000
# Polio                  0.648907
# total_expenditure      7.718579
# diphtheria             0.648907
# hiv                    0.000000
# thinness_10_19         1.092896
# thinness_5_9           1.092896
# income_comp            5.498634
# Schooling              5.464481
# life_expectancy_wb     0.000000
# population_wb          0.000000
# gdb_wb                 1.536885
# Country Category       0.000000
# dtype: float64

# %% [markdown]
# - add country classification

# %%
le3[le3['gdb_wb'].isnull()][['Country','Year']]
# Out:
#                                     Country  Year
# 14                              Afghanistan  2001
# 15                              Afghanistan  2000
# 704   Democratic People's Republic of Korea  2015
# 705   Democratic People's Republic of Korea  2014
# 706   Democratic People's Republic of Korea  2013
# 707   Democratic People's Republic of Korea  2012
# 708   Democratic People's Republic of Korea  2011
# 709   Democratic People's Republic of Korea  2010
# 710   Democratic People's Republic of Korea  2009
# 711   Democratic People's Republic of Korea  2008
# 712   Democratic People's Republic of Korea  2007
# 713   Democratic People's Republic of Korea  2006
# 714   Democratic People's Republic of Korea  2005
# 715   Democratic People's Republic of Korea  2004
# 716   Democratic People's Republic of Korea  2003
# 717   Democratic People's Republic of Korea  2002
# 718   Democratic People's Republic of Korea  2001
# 719   Democratic People's Republic of Korea  2000
# ...

# %%
le3.to_csv('life_expectancy_final.csv')
